# %%
def Our_Prediction():
    import pandas as pd
    import numpy as np
    import random
    from sklearn.utils import shuffle

    #Read data from excel
    data=pd.read_excel("C:\\Users\\Abhi\\Desktop\\Quiz.xls")

    #Code to set the Accuracy for users based on the topic
    random_range_male = [80,12,18,15,30,36,42,48,54,60,66,72,78,86,94]
    random_range_female = [6,12,18,15,30,36,42,48,54,60,66,72,78,86,94]
    for index,row in data.iterrows():
        no = index
        if(index<15):
            temp_accuracy = random.randrange(random_range_male[no]-5,random_range_male[no]+5)
            data.at[index,'Accuracy']=temp_accuracy
        else:
            no = no % 15
            temp_accuracy = random.randrange(random_range_female[no]-5,random_range_female[no]+5)
            data.at[index,'Accuracy']=temp_accuracy

    #Convert and set the new data with its Accuracy 
    data.to_csv('quiz_Dataset.csv',index=False) 

    # Importing the dataset
    dataset=pd.read_csv("C:\\Users\\Abhi\\quiz_Dataset.csv")
    X = dataset.iloc[:,[0,1,2,3,4,5,6]].values
    y = dataset.iloc[:, 7].values


    # Splitting the dataset into the Training set and Test set
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)


    # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)


    #Training the dataset
    from sklearn.ensemble import RandomForestClassifier
    reg=RandomForestClassifier()
    reg.fit(X_train,y_train)

    #Testing with a custom input
    prediction=reg.predict(sc.transform(np.array([[1,1,0,1,1,1,0]])))
    print(prediction)


Our_Prediction()
# Out:
# [7.]
# C:\Users\Abhi\AppData\Local\Programs\Python\Python37-32\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
dataset.head()
# Out:
#    Gender  T1  T2  T3  T4  T5  T6  Accuracy
# 0       0   0   0   1   1   1   1      81.0
# 1       0   1   0   0   1   1   1       7.0
# 2       0   1   1   0   0   1   1      22.0
# 3       0   1   1   1   0   0   1      15.0
# 4       0   1   1   1   1   0   0      25.0

# %%
import random
random_range_male = [80,12,18,15,30,36,42,48,54,60,66,72,78,86,94]
random_range_female = [6,12,18,15,30,36,42,48,54,60,66,72,78,86,94]

for index,row in data.iterrows():
    no = index
    if(index<15):
        temp_accuracy = random.randrange(random_range_male[no]-5,random_range_male[no]+5)
        data.at[index,'Accuracy']=temp_accuracy
    else:
        no = no % 15
        temp_accuracy = random.randrange(random_range_female[no]-5,random_range_female[no]+5)
        data.at[index,'Accuracy']=temp_accuracy

# %%
data.to_csv('xyz.csv',index=False)
# Importing the dataset
dataset=pd.read_csv("C:\\Users\\Abhi\\model_2.csv")
X = dataset.iloc[:,[0,1]].values
y = dataset.iloc[:, 2].values

# %%
import pandas as pd
import numpy as np
import random
import csv

nos = [0,1,2,3,4]
frequency = [0,0,0,0,0]
stop_frequency = [50,150,300,300,200]
range_start = [70,75,75,80,85]
range_end = [78,83,85,90,93]

no_gender=[0,1]

csv_data = [['Gender','Designation','Accuracy']]

count=1
while count <=1000:
    gender= random.choice(no_gender)
    random_no = random.choice(nos)
    frequency[random_no]+=1
    if(frequency[random_no]>=stop_frequency[random_no]):
        nos.remove(random_no)
    csv_data.append([gender,random_no,random.choice(range(range_start[random_no],range_end[random_no]+1))])
    count+=1
print(frequency)

rows = [random_no]
with open('model_2.csv', 'w',newline='') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerows(csv_data)
csvFile.close()

#Method to set threshold for predicted value
def custom_accuracy(y_test,y_pred,thresold):
    right = 0
    l = len(y_pred)
    for i in range(0,l):
        if(abs(y_pred[i]-y_test[i]) <= thresold):
            right += 1
    return ((right/l)*100)


# Importing the dataset
dataset=pd.read_csv("C:\\Users\\Abhi\\model_2.csv")
X = dataset.iloc[:,[0,1]].values
y = dataset.iloc[:, 2].values


# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)


# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)


# Training the dataset
from sklearn.tree import DecisionTreeClassifier
reg=DecisionTreeClassifier()
reg.fit(X_train,y_train)


# Testing the dataset on trained model
y_pred = reg.predict(X_test)
score = reg.score(X_test,y_test)*100
print("R square value:" , score)
print("Custom accuracy:" , custom_accuracy(y_test,y_pred,10))


# Testing with a custom input
#new_prediction = reg.predict(sc.transform(np.array([[1,1]])))
#print("Prediction score:" , new_prediction)

'''
list1=[]
for i in range(0,2):
    for j in range(0,5):
        list2=[reg.predict(sc.transform(np.array([[i,j]])))]
        print(list2[0])
        list1.append(list2)
        
print("maximum",max(list1)[0])

'''
# Out:
# [50, 150, 300, 300, 200]
# R square value: 5.0
# Custom accuracy: 100.0
# '\nlist1=[]\nfor i in range(0,2):\n    for j in range(0,5):\n        list2=[reg.predict(sc.transform(np.array([[i,j]])))]\n        print(list2[0])\n        list1.append(list2)\n        \nprint("maximum",max(list1)[0])\n\n'

# %%
def Question_Accuracy():
    import pandas as pd
    import numpy as np
    import array

    data=pd.read_excel("C:\\Users\\Abhi\\Desktop\\Quiz_new.xls")
    data.head()
    X = data.iloc[:,[0,1,2]].values
    y = data.iloc[:, 3].values


    # Splitting the dataset into the Training set and Test set
    from sklearn.model_selection import train_test_split

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

    # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)

    #Training the dataset
    from sklearn.ensemble import RandomForestClassifier
    reg=RandomForestClassifier()
    reg.fit(X_train,y_train)

    # Store Input in an array
    Total_Question=int(input("Total number of questions till now: " ))
    Correct_One=int(input("Total number of Correct questions till now: "))
    Complexity=int(input("Current Complexity: "))

    # Testing with a custom input
    prediction=reg.predict(sc.transform(np.array([[Total_Question,Correct_One,Complexity]])))
    print(prediction)

#Calling a Function to Predict the Accuracy after each question    
Question_Accuracy()
# Out:
# C:\Users\Abhi\AppData\Local\Programs\Python\Python37-32\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Total number of questions till now: 8
# Total number of Correct questions till now: 7
# Current Complexity: 1
# [86]
